# %%
import cv2
import os
import json

# %%
data_dir = "../data"
test1 = os.path.join(data_dir, "test-1")
test2 = os.path.join(data_dir, "test-2")

# %%
def get_all_files(path):
    return os.listdir(path)

# %%
def seperate_images_and_json(list_of_files):
    image_file_names = []
    json_file_names = []
    for file in list_of_files:
        cleaned = file.lower()
        name, ext = os.path.splitext(cleaned)
        if ext in [".jpg", ".jpeg", ".png"]:
            image_file_names.append(file)
        elif ext in [".json"]:
            json_file_names.append(file)
            
    return image_file_names, json_file_names

# %%
def load_image(path):
    return cv2.imread(path)

# %%
def crop_image(image, x, y, width, height):
    return image[y:y+width, x:x+height]

# %%
def get_bounding_box_coordinates(attributes):
    x = attributes["x"]
    y = attributes["y"]
    width = attributes["width"]
    height = attributes["height"]
    
    return x, y, width, height

# %%
def save_sub_image(output_directory, image, image_name, image_type, unique_id):
    output_name = "{}({})-{}.jpg".format(image_name, image_type, unique_id)
    output_path = os.path.join(output_directory, output_name)
    cv2.imwrite(output_path, image)

# %%
image_names, json_names = seperate_images_and_json(get_all_files(test1))

# %%
with open(os.path.join(test1, json_names[0]), "r") as file:
    json_data = json.load(file)

# %%
for image_file in json_data["_via_img_metadata"]:
    image_data = json_data["_via_img_metadata"][image_file]
    shapes = image_data["regions"]
    image_file_path = os.path.join(test1, image_data["filename"])
    img = load_image(image_file_path) 
    for id_number, shape in enumerate(shapes):
        x, y, width, height = get_bounding_box_coordinates(shape['shape_attributes'])
        cropped_item = crop_image(img, x, y, width, height)
        print(shape["region_attributes"])
        file_name = os.path.splitext(image_data["filename"])[0]
        try:
            region_type = file_name, shape["region_attributes"]["type"]
        except:
            region_type = "AHHHHHHHHHHHHHHHHHHHHHHHHHHHHH"
        save_sub_image("../output", cropped_item, file_name, region_type, id_number)
# Out:
# {'type': 'Teacher outfit'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Teacher outfit'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Book'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Book'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Poster/wall hanging'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# {'type': 'Object'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-5996c28da514> in <module>
#       6     for id_number, shape in enumerate(shapes):
#       7         x, y, width, height = get_bounding_box_coordinates(shape['shape_attributes'])
# ----> 8         cropped_item = crop_image(img, x, y, width, height)
#       9         print(shape["region_attributes"])
#      10         file_name = os.path.splitext(image_data["filename"])[0]
#
# <ipython-input-6-3d967505fa74> in crop_image(image, x, y, width, height)
#       1 def crop_image(image, x, y, width, height):
# ----> 2     return image[y:y+width, x:x+height]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
json_data["_via_img_metadata"]["user2780_3396.jpg97772"]
# Out:
# {'filename': 'user2780_3396.jpg',
#  'size': 97772,
#  'regions': [{'shape_attributes': {'name': 'rect',
#     'x': 9,
#     'y': 74,
#     'width': 161,
#     'height': 216},
#    'region_attributes': {'type': 'Poster/wall hanging'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 11,
#     'y': 292,
#     'width': 194,
#     'height': 241},
#    'region_attributes': {'type': 'Object'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 772,
#     'y': 68,
#     'width': 175,
#     'height': 214},
#    'region_attributes': {'type': 'Poster/wall hanging'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 7,
#     'y': 2,
#     'width': 942,
#     'height': 59},
#    'region_attributes': {'type': 'Poster/wall hanging'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 430,
#     'y': 62,
#     'width': 75,
#     'height': 114},
#    'region_attributes': {'type': 'Object'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 183,
#     'y': 65,
#     'width': 82,
#     'height': 110},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 270,
#     'y': 64,
#     'width': 87,
#     'height': 109},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 352,
#     'y': 71,
#     'width': 82,
#     'height': 100},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 500,
#     'y': 72,
#     'width': 85,
#     'height': 97},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 590,
#     'y': 64,
#     'width': 87,
#     'height': 108},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 673,
#     'y': 68,
#     'width': 89,
#     'height': 110},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 206,
#     'y': 188,
#     'width': 84,
#     'height': 112},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 285,
#     'y': 182,
#     'width': 85,
#     'height': 114},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 389,
#     'y': 184,
#     'width': 82,
#     'height': 109},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 468,
#     'y': 181,
#     'width': 79,
#     'height': 112},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 579,
#     'y': 187,
#     'width': 81,
#     'height': 118},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 652,
#     'y': 190,
#     'width': 79,
#     'height': 111},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 202,
#     'y': 317,
#     'width': 83,
#     'height': 120},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 288,
#     'y': 320,
#     'width': 80,
#     'height': 119},
#    'region_attributes': {}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 388,
#     'y': 317,
#     'width': 80,
#     'height': 118},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 473,
#     'y': 317,
#     'width': 74,
#     'height': 122},
#    'region_attributes': {'type': 'Book'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 567,
#     'y': 318,
#     'width': 81,
#     'height': 113},
#    'region_attributes': {'type': 'Book'}}],
#  'file_attributes': {}}
